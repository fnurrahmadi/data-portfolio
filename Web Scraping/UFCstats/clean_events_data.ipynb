# %%
import pandas as pd

# %%
file = 'event_details_ufc.csv'
df = pd.read_csv(file, sep=';')

# %%
df.head()
# Out:
#                                           event_link  \
# 0  http://www.ufcstats.com/event-details/901cddcb...
# 1  http://www.ufcstats.com/event-details/901cddcb...
# 2  http://www.ufcstats.com/event-details/901cddcb...
# 3  http://www.ufcstats.com/event-details/901cddcb...
# 4  http://www.ufcstats.com/event-details/901cddcb...
#
#                                           fight_link win_loss  \
# 0  http://www.ufcstats.com/fight-details/755202fc...      win
# 1  http://www.ufcstats.com/fight-details/755202fc...      NaN
# 2  http://www.ufcstats.com/fight-details/c501576b...      win
# 3  http://www.ufcstats.com/fight-details/c501576b...      NaN
# 4  http://www.ufcstats.com/fight-details/b0f4c778...      win
#
#                  fighter                                       fighter_link  \
# 0        Jailton Almeida  http://www.ufcstats.com/fighter-details/41e83a...
# 1  Jairzinho Rozenstruik  http://www.ufcstats.com/fighter-details/2cd428...
# ...

# %%
df['event_link'].unique()
# Out:
# array(['http://www.ufcstats.com/event-details/901cddcbfa079097',
#        'http://www.ufcstats.com/event-details/3c6976f8182d9527',
#        'http://www.ufcstats.com/event-details/51b1e2fd9872005b',
#        'http://www.ufcstats.com/event-details/6fb1ba67bef41b37',
#        'http://www.ufcstats.com/event-details/15b1b21cd743d652',
#        'http://www.ufcstats.com/event-details/3dc3022232b79c7a',
#        'http://www.ufcstats.com/event-details/aec273fcb765330d',
#        'http://www.ufcstats.com/event-details/e4bb7e483c4ad318',
#        'http://www.ufcstats.com/event-details/35080a7f406f9ab3',
#        'http://www.ufcstats.com/event-details/1ccff7f0cfdf85eb',
#        'http://www.ufcstats.com/event-details/806975e1b4f47b27',
#        'http://www.ufcstats.com/event-details/f21a3d68fb9df387',
#        'http://www.ufcstats.com/event-details/01dd4cdc2446f665',
#        'http://www.ufcstats.com/event-details/d26394fc0e8e880a',
# ...
